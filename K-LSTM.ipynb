# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_score, recall_score, f1_score
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Load dataset
def dataset():
    data = pd.read_csv('final-dataset.csv')
    X = data.drop(columns=['Signal', 'Label', 'Hurst Component'])
    y = data['Label']
    return X, y, X.columns

# Min-Max Scaling
def feature_scaling_min_max(X):
    return MinMaxScaler().fit_transform(X)

# Compute classification metrics
def performance_measures(model, x_test, y_test):
    y_pred = (model.predict(x_test) > 0.5).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = recall_score(y_test, y_pred)
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    return accuracy, precision, sensitivity, specificity, f1

# LSTM Model
def create_lstm(input_shape):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=input_shape),
        Dropout(0.3),
        LSTM(32),
        Dropout(0.3),
        Dense(16, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Experiment Pipeline
def run_experiment(selection_method, k):
    method_name = selection_method.__name__.replace("_", " ").title()
    print(f"\n🔹 Running {method_name} Feature Selection")

    X, y, feature_names = dataset()
    X = feature_scaling_min_max(X)

    selector = SelectKBest(selection_method, k=k)
    X_new = selector.fit_transform(X, y)
    selected_features = [feature_names[i] for i in selector.get_support(indices=True)]

    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=0)
    x_val, x_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=0)

    # Reshape input for LSTM (samples, timesteps, features)
    X_train = np.expand_dims(X_train, axis=1)
    x_val = np.expand_dims(x_val, axis=1)
    x_test = np.expand_dims(x_test, axis=1)

    # Class weights
    cw = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
    class_weights = dict(enumerate(cw))

    model = create_lstm((1, k))
    early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

    start_time = time.time()
    history = model.fit(X_train, y_train, epochs=500, batch_size=32,
                        validation_data=(x_val, y_val), class_weight=class_weights,
                        callbacks=[early_stop], verbose=1)
    execution_time = time.time() - start_time

    accuracy, precision, recall, specificity, f1 = performance_measures(model, x_test, y_test)

    # Accuracy and Loss plots
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.title(f"{method_name} - Accuracy")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"{method_name} - Loss")
    plt.legend()
    plt.show()

    # ROC Curve
    y_pred_probs = model.predict(x_test).ravel()
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{method_name} - ROC Curve")
    plt.legend(loc="lower right")
    plt.show()

    print(f"\n **{method_name} - Model Performance:**")
    print(f" Test Accuracy  : {accuracy:.4f}")
    print(f" Precision      : {precision:.4f}")
    print(f" Recall (Sens.) : {recall:.4f}")
    print(f" Specificity    : {specificity:.4f}")
    print(f" F1 Score       : {f1:.4f}")
    print(f" Execution Time : {execution_time:.2f} seconds")
    print(f" Selected Features: {selected_features}\n")

    return accuracy, precision, recall, specificity, f1, execution_time, selected_features

# Total Execution Timer
total_start_time = time.time()

# Run Experiments
for method in [chi2, f_classif, mutual_info_classif]:
    run_experiment(method, k=10)

total_end_time = time.time()
print(f"\n **Total Execution Time: {total_end_time - total_start_time:.2f} seconds**")
# Out:
# 🔹 Running Chi2 Feature Selection
# Epoch 1/500
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5285 - loss: 0.6932 - val_accuracy: 0.5048 - val_loss: 0.6925
# Epoch 2/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5124 - loss: 0.6925 - val_accuracy: 0.5667 - val_loss: 0.6915
# Epoch 3/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5470 - loss: 0.6904 - val_accuracy: 0.5762 - val_loss: 0.6882
# Epoch 4/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5703 - loss: 0.6841 - val_accuracy: 0.6000 - val_loss: 0.6811
# Epoch 5/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6006 - loss: 0.6689 - val_accuracy: 0.6095 - val_loss: 0.6783
# Epoch 6/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6876 - loss: 0.5943 - val_accuracy: 0.6190 - val_loss: 0.6541
# Epoch 129/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6853 - loss: 0.5997 - val_accuracy: 0.6190 - val_loss: 0.6556
# Epoch 130/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6628 - loss: 0.6177 - val_accuracy: 0.6000 - val_loss: 0.6568
# Epoch 131/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6656 - loss: 0.5989 - val_accuracy: 0.6190 - val_loss: 0.6574
# Epoch 132/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6714 - loss: 0.5972 - val_accuracy: 0.6286 - val_loss: 0.6556
# Epoch 133/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6950 - loss: 0.6041 - val_accuracy: 0.6286 - val_loss: 0.6551
# Epoch 134/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6520 - loss: 0.6153 - val_accuracy: 0.6095 - val_loss: 0.6564
# Epoch 135/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6791 - loss: 0.6052 - val_accuracy: 0.6286 - val_loss: 0.6558
# Epoch 136/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6544 - loss: 0.6092 - val_accuracy: 0.6048 - val_loss: 0.6550
# Epoch 137/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6593 - loss: 0.6069 - val_accuracy: 0.6143 - val_loss: 0.6585
# Epoch 138/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6775 - loss: 0.6067 - val_accuracy: 0.6048 - val_loss: 0.6535
# Epoch 139/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6729 - loss: 0.6029 - val_accuracy: 0.6190 - val_loss: 0.6638
# Epoch 140/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6628 - loss: 0.6194 - val_accuracy: 0.6095 - val_loss: 0.6554
# Epoch 141/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6910 - loss: 0.5866 - val_accuracy: 0.6000 - val_loss: 0.6542
# Epoch 142/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6988 - loss: 0.5912 - val_accuracy: 0.6095 - val_loss: 0.6536
# Epoch 143/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6717 - loss: 0.6054 - val_accuracy: 0.6048 - val_loss: 0.6535
# Epoch 144/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6889 - loss: 0.5921 - val_accuracy: 0.6190 - val_loss: 0.6545
# Epoch 145/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6875 - loss: 0.5967 - val_accuracy: 0.6190 - val_loss: 0.6506
# Epoch 146/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6872 - loss: 0.5977 - val_accuracy: 0.6238 - val_loss: 0.6574
# Epoch 147/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6953 - loss: 0.5853 - val_accuracy: 0.6143 - val_loss: 0.6586
# Epoch 148/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6770 - loss: 0.6066 - val_accuracy: 0.6048 - val_loss: 0.6513
# Epoch 149/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6813 - loss: 0.5978 - val_accuracy: 0.6000 - val_loss: 0.6557
# Epoch 150/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6831 - loss: 0.5870 - val_accuracy: 0.6143 - val_loss: 0.6526
# Epoch 151/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6755 - loss: 0.5947 - val_accuracy: 0.5952 - val_loss: 0.6526
# Epoch 152/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6518 - loss: 0.6107 - val_accuracy: 0.6143 - val_loss: 0.6529
# Epoch 153/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6822 - loss: 0.6014 - val_accuracy: 0.5952 - val_loss: 0.6567
# Epoch 154/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6673 - loss: 0.6166 - val_accuracy: 0.6143 - val_loss: 0.6538
# Epoch 155/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6740 - loss: 0.6051 - val_accuracy: 0.6143 - val_loss: 0.6585
# Epoch 156/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6903 - loss: 0.5937 - val_accuracy: 0.6143 - val_loss: 0.6522
# Epoch 157/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6899 - loss: 0.6099 - val_accuracy: 0.6143 - val_loss: 0.6514
# Epoch 158/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7120 - loss: 0.5828 - val_accuracy: 0.6143 - val_loss: 0.6521
# Epoch 159/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7017 - loss: 0.5932 - val_accuracy: 0.6095 - val_loss: 0.6524
# Epoch 160/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7038 - loss: 0.5841 - val_accuracy: 0.6190 - val_loss: 0.6563
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  **F Classif - Model Performance:**
#  Test Accuracy  : 0.6905
#  Precision      : 0.6667
#  Recall (Sens.) : 0.7500
#  Specificity    : 0.6321
#  F1 Score       : 0.7059
#  Execution Time : 25.60 seconds
#  Selected Features: ['Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Hjorth Mobility', 'Spectral Entropy']
#
#
# 🔹 Running Mutual Info Classif Feature Selection
# Epoch 1/500
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5056 - loss: 0.6932 - val_accuracy: 0.5048 - val_loss: 0.6928
# Epoch 2/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4735 - loss: 0.6928 - val_accuracy: 0.5048 - val_loss: 0.6925
# Epoch 3/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4820 - loss: 0.6920 - val_accuracy: 0.5048 - val_loss: 0.6915
# Epoch 4/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5136 - loss: 0.6888 - val_accuracy: 0.5048 - val_loss: 0.6894
# Epoch 5/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5864 - loss: 0.6841 - val_accuracy: 0.5143 - val_loss: 0.6866
# Epoch 6/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5118 - loss: 0.6770 - val_accuracy: 0.4952 - val_loss: 0.6855
# Epoch 7/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5467 - loss: 0.6667 - val_accuracy: 0.5333 - val_loss: 0.6831
# Epoch 8/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6114 - loss: 0.6749 - val_accuracy: 0.5333 - val_loss: 0.6854
# Epoch 9/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5867 - loss: 0.6630 - val_accuracy: 0.5048 - val_loss: 0.6827
# Epoch 10/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6218 - loss: 0.6666 - val_accuracy: 0.5095 - val_loss: 0.6883
# Epoch 11/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5956 - loss: 0.6686 - val_accuracy: 0.5381 - val_loss: 0.6848
# Epoch 12/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6042 - loss: 0.6696 - val_accuracy: 0.5429 - val_loss: 0.6858
# Epoch 13/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6105 - loss: 0.6740 - val_accuracy: 0.5524 - val_loss: 0.6860
# Epoch 14/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5995 - loss: 0.6620 - val_accuracy: 0.5238 - val_loss: 0.6883
# Epoch 15/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5982 - loss: 0.6581 - val_accuracy: 0.5429 - val_loss: 0.6865
# Epoch 16/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6442 - loss: 0.6426 - val_accuracy: 0.5476 - val_loss: 0.6842
# Epoch 17/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5792 - loss: 0.6637 - val_accuracy: 0.5524 - val_loss: 0.6853
# Epoch 18/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6254 - loss: 0.6598 - val_accuracy: 0.5524 - val_loss: 0.6840
# Epoch 19/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6203 - loss: 0.6539 - val_accuracy: 0.5524 - val_loss: 0.6854
# Epoch 20/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6313 - loss: 0.6608 - val_accuracy: 0.5476 - val_loss: 0.6839
# Epoch 21/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6046 - loss: 0.6534 - val_accuracy: 0.5714 - val_loss: 0.6837
# Epoch 22/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5963 - loss: 0.6609 - val_accuracy: 0.5762 - val_loss: 0.6831
# Epoch 23/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5933 - loss: 0.6640 - val_accuracy: 0.5762 - val_loss: 0.6834
# Epoch 24/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6119 - loss: 0.6597 - val_accuracy: 0.5810 - val_loss: 0.6837
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#  **Mutual Info Classif - Model Performance:**
#  Test Accuracy  : 0.5619
#  Precision      : 0.5353
#  Recall (Sens.) : 0.8750
#  Specificity    : 0.2547
#  F1 Score       : 0.6642
#  Execution Time : 5.38 seconds
#  Selected Features: ['RMS (µV)', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Variance', 'Hjorth Complexity', 'Spectral Entropy']
#
#
#  **Total Execution Time: 66.77 seconds**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# ---------------------------
# Load Dataset
# ---------------------------
def load_dataset():
    data = pd.read_csv('final-dataset.csv')
    X = data.drop(columns=['Signal', 'Label', 'Hurst Component'])
    y = data['Label']
    return X, y

# ---------------------------
# Feature Selection
# ---------------------------
def select_features(X, y, method, k=20):
    feature_names = X.columns

    if method == 'chi2':
        scaler = MinMaxScaler()
        X_scaled = scaler.fit_transform(X)
        selector = SelectKBest(score_func=chi2, k=k)
    elif method == 'f_classif':
        X_scaled = StandardScaler().fit_transform(X)
        selector = SelectKBest(score_func=f_classif, k=k)
    elif method == 'mutual_info':
        X_scaled = StandardScaler().fit_transform(X)
        selector = SelectKBest(score_func=mutual_info_classif, k=k)
    else:
        raise ValueError("Invalid method")

    selector.fit(X_scaled, y)
    selected_feature_names = feature_names[selector.get_support()]
    X_selected = selector.transform(X_scaled)
    
    return X_selected, selected_feature_names

# ---------------------------
# Build LSTM Model
# ---------------------------
def build_lstm_model(input_shape, units=128, loss='binary_crossentropy'):
    model = Sequential()
    model.add(LSTM(units, input_shape=input_shape))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    return model

# ---------------------------
# Train & Evaluate LSTM
# ---------------------------
def train_and_evaluate_lstm(X_selected, y, method_name, selected_feature_names):
    start_time = time.time()

    # Reshape for LSTM
    X_selected = X_selected.reshape((X_selected.shape[0], 1, X_selected.shape[1]))

    X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, stratify=y, random_state=42)

    model = build_lstm_model(input_shape=(1, X_selected.shape[2]))

    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    history = model.fit(X_train, y_train, epochs=50, batch_size=32,
                        validation_split=0.2, callbacks=[early_stop], verbose=0)

    # Evaluate
    y_pred_probs = model.predict(X_test).ravel()
    y_pred = (y_pred_probs > 0.5).astype("int32")

    test_acc = model.evaluate(X_test, y_test, verbose=0)[1]
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    sens = recall
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    spec = tn / (tn + fp)
    exec_time = time.time() - start_time

    # -----------------------
    # Accuracy & Loss Plot
    # -----------------------
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title(f'{method_name.upper()} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{method_name.upper()} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    # -----------------------
    # ROC Curve
    # -----------------------
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve ({method_name.upper()})")
    plt.legend(loc="lower right")
    plt.show()

    # -----------------------
    # Print Performance
    # -----------------------
    print(f"\n{method_name.upper()} LSTM Performance:")
    print(f" Accuracy     : {test_acc:.4f}")
    print(f" Precision    : {precision:.4f}")
    print(f" Recall       : {recall:.4f}")
    print(f" F1 Score     : {f1:.4f}")
    print(f" Sensitivity  : {sens:.4f}")
    print(f" Specificity  : {spec:.4f}")
    print(f" Time Taken   : {exec_time:.2f} seconds")
    print(f" Selected Features: {selected_feature_names.tolist()}\n")

    return test_acc, precision, recall, f1, sens, spec, selected_feature_names.tolist()

# ---------------------------
# Run for All Feature Methods
# ---------------------------
X, y = load_dataset()

for method in ['chi2', 'f_classif', 'mutual_info']:
    print(f"\n--- Running LSTM with {method.upper()} features ---")
    X_selected, selected_feature_names = select_features(X, y, method, k=20)
    train_and_evaluate_lstm(X_selected, y, method, selected_feature_names)
# Out:
# --- Running LSTM with CHI2 features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# CHI2 LSTM Performance:
#  Accuracy     : 0.6786
#  Precision    : 0.6562
#  Recall       : 0.7500
#  F1 Score     : 0.7000
#  Sensitivity  : 0.7500
#  Specificity  : 0.6071
#  Time Taken   : 6.93 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
#
#
# --- Running LSTM with F_CLASSIF features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# F_CLASSIF LSTM Performance:
#  Accuracy     : 0.7250
#  Precision    : 0.7114
#  Recall       : 0.7571
#  F1 Score     : 0.7336
#  Sensitivity  : 0.7571
#  Specificity  : 0.6929
#  Time Taken   : 6.96 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
#
#
# --- Running LSTM with MUTUAL_INFO features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# MUTUAL_INFO LSTM Performance:
#  Accuracy     : 0.7143
#  Precision    : 0.6974
#  Recall       : 0.7571
#  F1 Score     : 0.7260
#  Sensitivity  : 0.7571
#  Specificity  : 0.6714
#  Time Taken   : 7.23 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
