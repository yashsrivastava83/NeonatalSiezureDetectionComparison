# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_score, recall_score, f1_score
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Load dataset
def dataset():
    data = pd.read_csv('final-dataset.csv')
    X = data.drop(columns=['Signal', 'Label', 'Hurst Component'])
    y = data['Label']
    return X, y, X.columns

# Min-Max Scaling
def feature_scaling_min_max(X):
    return MinMaxScaler().fit_transform(X)

# Compute classification metrics
def performance_measures(model, x_test, y_test):
    y_pred = (model.predict(x_test) > 0.5).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = recall_score(y_test, y_pred)
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    return accuracy, precision, sensitivity, specificity, f1

# Feedforward Neural Network Model
def create_ffnn(input_dim):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_dim,)),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Experiment Pipeline
def run_experiment(selection_method, k):
    method_name = selection_method.__name__.replace("_", " ").title()
    print(f"\n🔹 Running {method_name} Feature Selection")

    X, y, feature_names = dataset()
    X = feature_scaling_min_max(X)

    selector = SelectKBest(selection_method, k=k)
    X_new = selector.fit_transform(X, y)
    selected_features = [feature_names[i] for i in selector.get_support(indices=True)]

    X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=0)
    x_val, x_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=0)

    # Compute class weights for imbalance
    cw = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
    class_weights = dict(enumerate(cw))

    model = create_ffnn(X_train.shape[1])
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    start_time = time.time()
    history = model.fit(X_train, y_train, epochs=500, batch_size=32,
                        validation_data=(x_val, y_val), class_weight=class_weights,
                        callbacks=[early_stop], verbose=1)
    execution_time = time.time() - start_time

    accuracy, precision, recall, specificity, f1 = performance_measures(model, x_test, y_test)

    # Accuracy and Loss plots
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.title(f"{method_name} - Accuracy")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"{method_name} - Loss")
    plt.legend()
    plt.show()

    # ROC Curve
    y_pred_probs = model.predict(x_test).ravel()
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{method_name} - ROC Curve")
    plt.legend(loc="lower right")
    plt.show()

    print(f"\n **{method_name} - Model Performance:**")
    print(f" Test Accuracy  : {accuracy:.4f}")
    print(f" Precision      : {precision:.4f}")
    print(f" Recall (Sens.) : {recall:.4f}")
    print(f" Specificity    : {specificity:.4f}")
    print(f" F1 Score       : {f1:.4f}")
    print(f" Execution Time : {execution_time:.2f} seconds")
    print(f" Selected Features: {selected_features}\n")

    return accuracy, precision, recall, specificity, f1, execution_time, selected_features

# Total Execution Timer
total_start_time = time.time()

# Run Experiments
for method in [chi2, f_classif, mutual_info_classif]:
    run_experiment(method, k=10)

total_end_time = time.time()
print(f"\n **Total Execution Time: {total_end_time - total_start_time:.2f} seconds**")
# Out:
# 🔹 Running Chi2 Feature Selection
# Epoch 1/500
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5384 - loss: 0.6883 - val_accuracy: 0.6095 - val_loss: 0.6821
# Epoch 2/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5904 - loss: 0.6745 - val_accuracy: 0.5952 - val_loss: 0.6769
# Epoch 3/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6138 - loss: 0.6670 - val_accuracy: 0.5905 - val_loss: 0.6741
# Epoch 4/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6150 - loss: 0.6584 - val_accuracy: 0.5810 - val_loss: 0.6736
# Epoch 5/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5867 - loss: 0.6582 - val_accuracy: 0.5667 - val_loss: 0.6745
# Epoch 6/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6110 - loss: 0.6465 - val_accuracy: 0.5810 - val_loss: 0.6729
# Epoch 7/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7519 - loss: 0.5241 - val_accuracy: 0.7048 - val_loss: 0.6078
# Epoch 191/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7511 - loss: 0.5369 - val_accuracy: 0.6762 - val_loss: 0.6054
# Epoch 192/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7127 - loss: 0.5453 - val_accuracy: 0.6714 - val_loss: 0.6114
# Epoch 193/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7013 - loss: 0.5340 - val_accuracy: 0.6762 - val_loss: 0.6121
# Epoch 194/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6930 - loss: 0.5694 - val_accuracy: 0.6952 - val_loss: 0.6068
# Epoch 195/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7290 - loss: 0.5206 - val_accuracy: 0.6857 - val_loss: 0.6104
# Epoch 196/500
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - loss: 0.5113 - val_accuracy: 0.6810 - val_loss: 0.6092
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#  **Mutual Info Classif - Model Performance:**
#  Test Accuracy  : 0.7381
#  Precision      : 0.7290
#  Recall (Sens.) : 0.7500
#  Specificity    : 0.7264
#  F1 Score       : 0.7393
#  Execution Time : 22.43 seconds
#  Selected Features: ['RMS (µV)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Variance', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
#
#
#  **Total Execution Time: 58.78 seconds**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.callbacks import EarlyStopping

# ---------------------------
# Load Dataset
# ---------------------------
def load_dataset():
    data = pd.read_csv('final-dataset.csv')
    X = data.drop(columns=['Signal', 'Label', 'Hurst Component'])
    y = data['Label']
    return X, y

# ---------------------------
# Feature Selection
# ---------------------------
def select_features(X, y, method, k=20):
    feature_names = X.columns

    if method == 'chi2':
        scaler = MinMaxScaler()
        X_scaled = scaler.fit_transform(X)
        selector = SelectKBest(score_func=chi2, k=k)
    elif method == 'f_classif':
        X_scaled = StandardScaler().fit_transform(X)
        selector = SelectKBest(score_func=f_classif, k=k)
    elif method == 'mutual_info':
        X_scaled = StandardScaler().fit_transform(X)
        selector = SelectKBest(score_func=mutual_info_classif, k=k)
    else:
        raise ValueError("Invalid method")

    selector.fit(X_scaled, y)
    selected_feature_names = feature_names[selector.get_support()]
    X_selected = selector.transform(X_scaled)

    return X_selected, selected_feature_names

# ---------------------------
# Build RNN Model
# ---------------------------
def build_rnn_model(input_shape, units=128, loss='binary_crossentropy'):
    model = Sequential()
    model.add(SimpleRNN(units, input_shape=input_shape))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    return model

# ---------------------------
# Train & Evaluate RNN
# ---------------------------
def train_and_evaluate_rnn(X_selected, y, method_name, selected_feature_names):
    start_time = time.time()

    # Reshape for RNN
    X_selected = X_selected.reshape((X_selected.shape[0], 1, X_selected.shape[1]))

    X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, stratify=y, random_state=42)

    model = build_rnn_model(input_shape=(1, X_selected.shape[2]))

    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    history = model.fit(X_train, y_train, epochs=50, batch_size=32,
                        validation_split=0.2, callbacks=[early_stop], verbose=0)

    # Evaluate
    y_pred_probs = model.predict(X_test).ravel()
    y_pred = (y_pred_probs > 0.5).astype("int32")

    test_acc = model.evaluate(X_test, y_test, verbose=0)[1]
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    sens = recall
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    spec = tn / (tn + fp)
    exec_time = time.time() - start_time

    # -----------------------
    # Accuracy & Loss Plot
    # -----------------------
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title(f'{method_name.upper()} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{method_name.upper()} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    # -----------------------
    # ROC Curve
    # -----------------------
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve ({method_name.upper()})")
    plt.legend(loc="lower right")
    plt.show()

    # -----------------------
    # Print Performance
    # -----------------------
    print(f"\n{method_name.upper()} RNN Performance:")
    print(f" Accuracy     : {test_acc:.4f}")
    print(f" Precision    : {precision:.4f}")
    print(f" Recall       : {recall:.4f}")
    print(f" F1 Score     : {f1:.4f}")
    print(f" Sensitivity  : {sens:.4f}")
    print(f" Specificity  : {spec:.4f}")
    print(f" Time Taken   : {exec_time:.2f} seconds")
    print(f" Selected Features: {selected_feature_names.tolist()}\n")

    return test_acc, precision, recall, f1, sens, spec, selected_feature_names.tolist()

# ---------------------------
# Run for All Feature Methods
# ---------------------------
X, y = load_dataset()

for method in ['chi2', 'f_classif', 'mutual_info']:
    print(f"\n--- Running RNN with {method.upper()} features ---")
    X_selected, selected_feature_names = select_features(X, y, method, k=20)
    train_and_evaluate_rnn(X_selected, y, method, selected_feature_names)
# Out:
# --- Running RNN with CHI2 features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# CHI2 RNN Performance:
#  Accuracy     : 0.6714
#  Precision    : 0.6481
#  Recall       : 0.7500
#  F1 Score     : 0.6954
#  Sensitivity  : 0.7500
#  Specificity  : 0.5929
#  Time Taken   : 6.00 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
#
#
# --- Running RNN with F_CLASSIF features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# F_CLASSIF RNN Performance:
#  Accuracy     : 0.6964
#  Precision    : 0.6846
#  Recall       : 0.7286
#  F1 Score     : 0.7059
#  Sensitivity  : 0.7286
#  Specificity  : 0.6643
#  Time Taken   : 6.22 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
#
#
# --- Running RNN with MUTUAL_INFO features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# MUTUAL_INFO RNN Performance:
#  Accuracy     : 0.7143
#  Precision    : 0.7143
#  Recall       : 0.7143
#  F1 Score     : 0.7143
#  Sensitivity  : 0.7143
#  Specificity  : 0.7143
#  Time Taken   : 6.20 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# ---------------------------
# Load Dataset
# ---------------------------
def load_dataset():
    data = pd.read_csv('final-dataset.csv')
    X = data.drop(columns=['Signal', 'Label', 'Hurst Component'])
    y = data['Label']
    return X, y

# ---------------------------
# Feature Selection
# ---------------------------
def select_features(X, y, method, k=20):
    feature_names = X.columns

    if method == 'chi2':
        scaler = MinMaxScaler()
        X_scaled = scaler.fit_transform(X)
        selector = SelectKBest(score_func=chi2, k=k)
    elif method == 'f_classif':
        X_scaled = StandardScaler().fit_transform(X)
        selector = SelectKBest(score_func=f_classif, k=k)
    elif method == 'mutual_info':
        X_scaled = StandardScaler().fit_transform(X)
        selector = SelectKBest(score_func=mutual_info_classif, k=k)
    else:
        raise ValueError("Invalid method. Choose from 'chi2', 'f_classif', or 'mutual_info'.")

    selector.fit(X_scaled, y)
    selected_feature_names = feature_names[selector.get_support()]
    X_selected = selector.transform(X_scaled)

    return X_selected, selected_feature_names

# ---------------------------
# Build RNN Model
# ---------------------------
def build_rnn_model(input_shape, units=128, loss='binary_crossentropy'):
    model = Sequential()
    model.add(SimpleRNN(units, input_shape=input_shape))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    return model

# ---------------------------
# Train & Evaluate RNN
# ---------------------------
def train_and_evaluate_rnn(X_selected, y, method_name, selected_feature_names):
    start_time = time.time()

    # Reshape for RNN input: (samples, timesteps=1, features)
    X_selected = X_selected.reshape((X_selected.shape[0], 1, X_selected.shape[1]))

    # Train-Test split with stratification
    X_train, X_test, y_train, y_test = train_test_split(
        X_selected, y, test_size=0.2, stratify=y, random_state=42
    )

    model = build_rnn_model(input_shape=(1, X_selected.shape[2]))

    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    history = model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_split=0.2,
        callbacks=[early_stop],
        verbose=0
    )

    # Save the trained model
    model_filename = f"rnn_model_{method_name}.h5"
    model.save(model_filename)
    print(f"Saved trained model to {model_filename}")

    # Predict probabilities and classes
    y_pred_probs = model.predict(X_test).ravel()
    y_pred = (y_pred_probs > 0.5).astype(int)

    # Evaluate metrics
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    sens = recall
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    spec = tn / (tn + fp)
    exec_time = time.time() - start_time

    # Plot accuracy & loss
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title(f'{method_name.upper()} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{method_name.upper()} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    # Plot ROC curve
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve ({method_name.upper()})")
    plt.legend(loc="lower right")
    plt.show()

    # Print performance
    print(f"\n{method_name.upper()} RNN Performance:")
    print(f" Accuracy     : {test_acc:.4f}")
    print(f" Precision    : {precision:.4f}")
    print(f" Recall       : {recall:.4f}")
    print(f" F1 Score     : {f1:.4f}")
    print(f" Sensitivity  : {sens:.4f}")
    print(f" Specificity  : {spec:.4f}")
    print(f" Time Taken   : {exec_time:.2f} seconds")
    print(f" Selected Features: {selected_feature_names.tolist()}\n")

    return test_acc, precision, recall, f1, sens, spec, selected_feature_names.tolist()

# ---------------------------
# Run for All Feature Selection Methods
# ---------------------------
if __name__ == "__main__":
    X, y = load_dataset()

    for method in ['chi2', 'f_classif', 'mutual_info']:
        print(f"\n--- Running RNN with {method.upper()} features ---")
        X_selected, selected_feature_names = select_features(X, y, method, k=20)
        train_and_evaluate_rnn(X_selected, y, method, selected_feature_names)
# Out:
# --- Running RNN with CHI2 features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved trained model to rnn_model_chi2.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# CHI2 RNN Performance:
#  Accuracy     : 0.6750
#  Precision    : 0.6522
#  Recall       : 0.7500
#  F1 Score     : 0.6977
#  Sensitivity  : 0.7500
#  Specificity  : 0.6000
#  Time Taken   : 5.82 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
#
#
# --- Running RNN with F_CLASSIF features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved trained model to rnn_model_f_classif.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# F_CLASSIF RNN Performance:
#  Accuracy     : 0.7071
#  Precision    : 0.7014
#  Recall       : 0.7214
#  F1 Score     : 0.7113
#  Sensitivity  : 0.7214
#  Specificity  : 0.6929
#  Time Taken   : 6.10 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
#
#
# --- Running RNN with MUTUAL_INFO features ---
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=20 is greater than n_features=16. All the features will be returned.
#   warnings.warn(
# c:\Users\Yash Srivastava\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved trained model to rnn_model_mutual_info.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# MUTUAL_INFO RNN Performance:
#  Accuracy     : 0.6964
#  Precision    : 0.6797
#  Recall       : 0.7429
#  F1 Score     : 0.7099
#  Sensitivity  : 0.7429
#  Specificity  : 0.6500
#  Time Taken   : 5.48 seconds
#  Selected Features: ['Mean (µV)', 'RMS (µV)', 'MRS (µV)', 'Zero Crossings', 'Frequency (Hz)', 'Delta (µV² /Hz)', 'Theta (µV² /Hz)', 'Alpha (µV² /Hz)', 'Beta (µV² /Hz)', 'Gamma (µV² /Hz)', 'Skewness', 'Variance', 'Kurtosis', 'Hjorth Mobility', 'Hjorth Complexity', 'Spectral Entropy']
