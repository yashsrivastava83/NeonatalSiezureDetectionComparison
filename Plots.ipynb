# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# Creating the comparison table with a unique serial number for each algorithm
data = {
    'Sr No': [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6, 7, 7, 7, 8, 8, 8],
    'Model': ['Decision Tree', 'Decision Tree', 'Decision Tree', 'Logistic Reg.', 'Logistic Reg.', 'Logistic Reg.',
              'Random Forest', 'Random Forest', 'Random Forest', 'SVM', 'SVM', 'SVM', 'KNN', 'KNN', 'KNN',
              'GRU', 'GRU', 'GRU', 'LSTM', 'LSTM', 'LSTM', 'RNN', 'RNN', 'RNN'],
    'Feature Selection': ['Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info',
                          'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info',
                          'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info'],
    'Accuracy': [0.7476, 0.7476, 0.8333, 0.6381, 0.6381, 0.5619, 0.8905, 0.8905, 0.8952, 0.6238, 0.7905, 0.7476, 0.6571,
                 0.7048, 0.6714, 0.8165, 0.8354, 0.8239, 0.8094, 0.8251, 0.8189, 0.8034, 0.8203, 0.8150],
    'Precision': [0.7008, 0.7008, 0.8165, 0.6207, 0.6207, 0.5462, 0.8932, 0.8932, 0.9020, 0.5767, 0.7632, 0.7257, 0.6633,
                  0.6810, 0.6522, 0.8065, 0.8201, 0.8149, 0.8031, 0.8148, 0.8117, 0.7923, 0.8062, 0.8036],
    'Recall (Sensitivity)': [0.8558, 0.8558, 0.8558, 0.6923, 0.6923, 0.6827, 0.8846, 0.8846, 0.8846, 0.9038, 0.8365, 0.7885, 0.6250,
                             0.7596, 0.7212, 0.8237, 0.8403, 0.8294, 0.8202, 0.8304, 0.8261, 0.8146, 0.8239, 0.8240],
    'Specificity': [0.6415, 0.6415, 0.8113, 0.5849, 0.5849, 0.4434, 0.8962, 0.8962, 0.9057, 0.3491, 0.7453, 0.7075, 0.6887,
                    0.6509, 0.6226, 0.8037, 0.8064, 0.8087, 0.7903, 0.8030, 0.7974, 0.7819, 0.7958, 0.7916],
    'F1-Score': [0.7706, 0.7706, 0.8357, 0.6545, 0.6545, 0.6068, 0.8889, 0.8889, 0.8932, 0.7041, 0.7982, 0.7558, 0.6436,
                 0.7182, 0.6849, 0.8150, 0.8282, 0.8215, 0.8115, 0.8217, 0.8190, 0.8034, 0.8148, 0.8124]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Adjusting the table for readability
df['Model'] = df['Model'] + ' (' + df['Feature Selection'] + ')'

# Display the comparison table
df.drop(columns='Feature Selection', inplace=True)
df.set_index(['Sr No', 'Model'], inplace=True)

df
# Out:
#                                    Accuracy  Precision  Recall (Sensitivity)  \
# Sr No Model
# 1     Decision Tree (Chi2)           0.7476     0.7008                0.8558
#       Decision Tree (F_classif)      0.7476     0.7008                0.8558
#       Decision Tree (Mutual_Info)    0.8333     0.8165                0.8558
# 2     Logistic Reg. (Chi2)           0.6381     0.6207                0.6923
#       Logistic Reg. (F_classif)      0.6381     0.6207                0.6923
#       Logistic Reg. (Mutual_Info)    0.5619     0.5462                0.6827
# 3     Random Forest (Chi2)           0.8905     0.8932                0.8846
#       Random Forest (F_classif)      0.8905     0.8932                0.8846
#       Random Forest (Mutual_Info)    0.8952     0.9020                0.8846
# 4     SVM (Chi2)                     0.6238     0.5767                0.9038
#       SVM (F_classif)                0.7905     0.7632                0.8365
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Data as you provided
data = {
    'Sr No': [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6, 7, 7, 7, 8, 8, 8],
    'Model': ['Decision Tree', 'Decision Tree', 'Decision Tree', 'Logistic Reg.', 'Logistic Reg.', 'Logistic Reg.',
              'Random Forest', 'Random Forest', 'Random Forest', 'SVM', 'SVM', 'SVM', 'KNN', 'KNN', 'KNN',
              'GRU', 'GRU', 'GRU', 'LSTM', 'LSTM', 'LSTM', 'RNN', 'RNN', 'RNN'],
    'Feature Selection': ['Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info',
                          'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info',
                          'Chi2', 'F_classif', 'Mutual_Info', 'Chi2', 'F_classif', 'Mutual_Info'],
    'Accuracy': [0.7476, 0.7476, 0.8333, 0.6381, 0.6381, 0.5619, 0.8905, 0.8905, 0.8952, 0.6238, 0.7905, 0.7476, 0.6571,
                 0.7048, 0.6714, 0.8165, 0.8354, 0.8239, 0.8094, 0.8251, 0.8189, 0.8034, 0.8203, 0.8150],
    'Precision': [0.7008, 0.7008, 0.8165, 0.6207, 0.6207, 0.5462, 0.8932, 0.8932, 0.9020, 0.5767, 0.7632, 0.7257, 0.6633,
                  0.6810, 0.6522, 0.8065, 0.8201, 0.8149, 0.8031, 0.8148, 0.8117, 0.7923, 0.8062, 0.8036],
    'Recall (Sensitivity)': [0.8558, 0.8558, 0.8558, 0.6923, 0.6923, 0.6827, 0.8846, 0.8846, 0.8846, 0.9038, 0.8365, 0.7885, 0.6250,
                             0.7596, 0.7212, 0.8237, 0.8403, 0.8294, 0.8202, 0.8304, 0.8261, 0.8146, 0.8239, 0.8240],
    'Specificity': [0.6415, 0.6415, 0.8113, 0.5849, 0.5849, 0.4434, 0.8962, 0.8962, 0.9057, 0.3491, 0.7453, 0.7075, 0.6887,
                    0.6509, 0.6226, 0.8037, 0.8064, 0.8087, 0.7903, 0.8030, 0.7974, 0.7819, 0.7958, 0.7916],
    'F1-Score': [0.7706, 0.7706, 0.8357, 0.6545, 0.6545, 0.6068, 0.8889, 0.8889, 0.8932, 0.7041, 0.7982, 0.7558, 0.6436,
                 0.7182, 0.6849, 0.8150, 0.8282, 0.8215, 0.8115, 0.8217, 0.8190, 0.8034, 0.8148, 0.8124]
}

# Create DataFrame
df = pd.DataFrame(data)

# Clean columns (just in case)
df.columns = df.columns.str.strip()

# Create combined label column for y-axis
df['Model - Feature'] = df['Model'] + ' - ' + df['Feature Selection']

# Extract numeric columns only (drop all non-numeric)
heatmap_data = df.drop(columns=['Sr No', 'Model', 'Feature Selection', 'Model - Feature']).astype(float)

# Plotting heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="YlGnBu", cbar=True)

plt.title("Model Comparison Heatmap")
plt.xticks(rotation=45)
plt.yticks(ticks=np.arange(len(df)), labels=df['Model - Feature'], rotation=0)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df is the DataFrame with Model, Feature Selection, and metrics columns
metrics = ['Accuracy', 'Precision', 'Recall (Sensitivity)', 'F1-Score']

df_metrics_all = df[['Model', 'Feature Selection'] + metrics]

plt.figure(figsize=(15, 8))

sns.barplot(data=df_metrics_all.melt(id_vars=['Model', 'Feature Selection'], value_vars=metrics),
            x='Model', y='value', hue='variable', ci=None)

plt.title('Performance Comparison of All Algorithms')
plt.xlabel('Models')
plt.ylabel('Scores')
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend(title='Metrics')

ax = plt.gca()
for p in ax.patches:
    height = p.get_height()
    y_offset = height + 0.02
    if height < 0.1:
        y_offset = height + 0.05
    ax.annotate(f'{height*100:.1f}%', 
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom',
                fontsize=10, color='black',
                xytext=(0, y_offset - height), textcoords='offset points')

plt.show()
# Out:
# C:\Users\Yash Srivastava\AppData\Local\Temp\ipykernel_22164\2593433533.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_metrics_all.melt(id_vars=['Model', 'Feature Selection'], value_vars=metrics),

# %%
import matplotlib.pyplot as plt

# Reset index to bring 'Model' back as a column
df_reset = df.reset_index()

# Set 'Model' as index and select the metric columns
df_plot = df_reset.set_index('Model')[['Accuracy', 'Precision', 'Recall (Sensitivity)', 'F1-Score']]

# Plot
ax = df_plot.plot(kind='bar', figsize=(18, 10), width=0.8)

# Titles and labels
plt.title('Performance Comparison of All Algorithms')
plt.xlabel('Model and Feature Selection')
plt.ylabel('Scores')
plt.xticks(rotation=90)
plt.tight_layout()

# Annotate values
for p in ax.patches:
    height = p.get_height()
    x_pos = p.get_x() + p.get_width() / 2.
    ax.annotate(f'{height:.2f}',
                (x_pos, height),
                ha='center', va='bottom',
                fontsize=8, color='black',
                rotation=90,
                xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# After fine tuning

# %%
# import pandas as pd

# # Data for all models
# data = [
#     # Traditional ML Models
#     ['KNN', 'Chi2', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.22],
#     ['KNN', 'F_classif', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.04],
#     ['KNN', 'Mutual_Info', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.04],

#     ['SVM', 'Chi2', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.15],
#     ['SVM', 'F_classif', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.14],
#     ['SVM', 'Mutual_Info', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.16],

#     ['Logistic Reg.', 'Chi2', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.02],
#     ['Logistic Reg.', 'F_classif', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.01],
#     ['Logistic Reg.', 'Mutual_Info', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.01],

#     ['Random Forest', 'Chi2', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.35],
#     ['Random Forest', 'F_classif', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.33],
#     ['Random Forest', 'Mutual_Info', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.35],

#     ['Decision Tree', 'Chi2', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.03],
#     ['Decision Tree', 'F_classif', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.03],
#     ['Decision Tree', 'Mutual_Info', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.02],

#     # RNN
#     ['RNN', 'Chi2', 0.6714, 0.6481, 0.7500, 0.6954, 0.7500, 0.5929, 6.00],
#     ['RNN', 'F_classif', 0.6964, 0.6846, 0.7286, 0.7059, 0.7286, 0.6643, 6.22],
#     ['RNN', 'Mutual_Info', 0.7143, 0.7143, 0.7143, 0.7143, 0.7143, 0.7143, 6.20],

#     # LSTM
#     ['LSTM', 'Chi2', 0.6786, 0.6562, 0.7500, 0.7000, 0.7500, 0.6071, 6.93],
#     ['LSTM', 'F_classif', 0.7250, 0.7114, 0.7571, 0.7336, 0.7571, 0.6929, 6.96],
#     ['LSTM', 'Mutual_Info', 0.7143, 0.6974, 0.7571, 0.7260, 0.7571, 0.6714, 7.23],

#     # GRU
#     ['GRU', 'Chi2', 0.6750, 0.6522, 0.7500, 0.6977, 0.7500, 0.6000, 6.05],
#     ['GRU', 'F_classif', 0.7071, 0.6859, 0.7643, 0.7230, 0.7643, 0.6500, 6.87],
#     ['GRU', 'Mutual_Info', 0.7214, 0.7039, 0.7643, 0.7329, 0.7643, 0.6786, 6.89],
# ]

# # Define column names
# columns = ['Model', 'Feature Selection', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Sensitivity', 'Specificity', 'Time (s)']

# # Create DataFrame
# df = pd.DataFrame(data, columns=columns)

# # Display the table
# print(df)

import pandas as pd

# Your data and columns
data = [
    ['KNN', 'Chi2', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.22],
    ['KNN', 'F_classif', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.04],
    ['KNN', 'Mutual_Info', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.04],
    ['SVM', 'Chi2', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.15],
    ['SVM', 'F_classif', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.14],
    ['SVM', 'Mutual_Info', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.16],
    ['Logistic Reg.', 'Chi2', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.02],
    ['Logistic Reg.', 'F_classif', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.01],
    ['Logistic Reg.', 'Mutual_Info', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.01],
    ['Random Forest', 'Chi2', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.35],
    ['Random Forest', 'F_classif', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.33],
    ['Random Forest', 'Mutual_Info', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.35],
    ['Decision Tree', 'Chi2', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.03],
    ['Decision Tree', 'F_classif', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.03],
    ['Decision Tree', 'Mutual_Info', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.02],
    ['RNN', 'Chi2', 0.6714, 0.6481, 0.7500, 0.6954, 0.7500, 0.5929, 6.00],
    ['RNN', 'F_classif', 0.6964, 0.6846, 0.7286, 0.7059, 0.7286, 0.6643, 6.22],
    ['RNN', 'Mutual_Info', 0.7143, 0.7143, 0.7143, 0.7143, 0.7143, 0.7143, 6.20],
    ['LSTM', 'Chi2', 0.6786, 0.6562, 0.7500, 0.7000, 0.7500, 0.6071, 6.93],
    ['LSTM', 'F_classif', 0.7250, 0.7114, 0.7571, 0.7336, 0.7571, 0.6929, 6.96],
    ['LSTM', 'Mutual_Info', 0.7143, 0.6974, 0.7571, 0.7260, 0.7571, 0.6714, 7.23],
    ['GRU', 'Chi2', 0.6750, 0.6522, 0.7500, 0.6977, 0.7500, 0.6000, 6.05],
    ['GRU', 'F_classif', 0.7071, 0.6859, 0.7643, 0.7230, 0.7643, 0.6500, 6.87],
    ['GRU', 'Mutual_Info', 0.7214, 0.7039, 0.7643, 0.7329, 0.7643, 0.6786, 6.89],
]

columns = ['Model', 'Feature Selection', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Sensitivity', 'Specificity', 'Time (s)']

df = pd.DataFrame(data, columns=columns)

# Sort by Accuracy descending
df_sorted = df.sort_values(by='Accuracy', ascending=False).reset_index(drop=True)

print(df_sorted)
# Out:
#             Model Feature Selection  Accuracy  Precision  Recall  F1 Score  \
# 0   Random Forest         F_classif    0.9036     0.9007  0.9071    0.9039
# 1   Random Forest       Mutual_Info    0.9036     0.9007  0.9071    0.9039
# 2   Random Forest              Chi2    0.9036     0.9007  0.9071    0.9039
# 3   Decision Tree              Chi2    0.7893     0.7755  0.8143    0.7944
# 4   Decision Tree         F_classif    0.7893     0.7755  0.8143    0.7944
# 5   Decision Tree       Mutual_Info    0.7893     0.7755  0.8143    0.7944
# 6             KNN              Chi2    0.7643     0.7372  0.8214    0.7770
# 7             KNN         F_classif    0.7643     0.7372  0.8214    0.7770
# 8             KNN       Mutual_Info    0.7643     0.7372  0.8214    0.7770
# 9             SVM              Chi2    0.7464     0.7143  0.8214    0.7641
# 10            SVM       Mutual_Info    0.7464     0.7143  0.8214    0.7641
# ...

# %%
# Sort the DataFrame by 'Accuracy' descending (highest accuracy first)
df_sorted = df.sort_values(by='Accuracy', ascending=False).reset_index(drop=True)

# Check if sorted correctly
is_sorted_desc = all(df_sorted['Accuracy'].iloc[i] >= df_sorted['Accuracy'].iloc[i+1] for i in range(len(df_sorted)-1))

print("Is the accuracy column sorted in descending order?", is_sorted_desc)
print(df_sorted[['Model', 'Feature Selection', 'Accuracy']])
# Out:
# Is the accuracy column sorted in descending order? True
#             Model Feature Selection  Accuracy
# 0   Random Forest         F_classif    0.9036
# 1   Random Forest       Mutual_Info    0.9036
# 2   Random Forest              Chi2    0.9036
# 3   Decision Tree              Chi2    0.7893
# 4   Decision Tree         F_classif    0.7893
# 5   Decision Tree       Mutual_Info    0.7893
# 6             KNN              Chi2    0.7643
# 7             KNN         F_classif    0.7643
# 8             KNN       Mutual_Info    0.7643
# 9             SVM              Chi2    0.7464
# 10            SVM       Mutual_Info    0.7464
# 11            SVM         F_classif    0.7464
# 12           LSTM         F_classif    0.7250
# 13            GRU       Mutual_Info    0.7214
# 14           LSTM       Mutual_Info    0.7143
# 15            RNN       Mutual_Info    0.7143
# 16            GRU         F_classif    0.7071
# 17            RNN         F_classif    0.6964
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data setup
data = [
    ['KNN', 'Chi2', 0.7643], ['KNN', 'F_classif', 0.7643], ['KNN', 'Mutual_Info', 0.7643],
    ['SVM', 'Chi2', 0.7464], ['SVM', 'F_classif', 0.7464], ['SVM', 'Mutual_Info', 0.7464],
    ['Logistic Reg.', 'Chi2', 0.6821], ['Logistic Reg.', 'F_classif', 0.6821], ['Logistic Reg.', 'Mutual_Info', 0.6821],
    ['Random Forest', 'Chi2', 0.9036], ['Random Forest', 'F_classif', 0.9036], ['Random Forest', 'Mutual_Info', 0.9036],
    ['Decision Tree', 'Chi2', 0.7893], ['Decision Tree', 'F_classif', 0.7893], ['Decision Tree', 'Mutual_Info', 0.7893],
    ['RNN', 'Chi2', 0.6714], ['RNN', 'F_classif', 0.6964], ['RNN', 'Mutual_Info', 0.7143],
    ['LSTM', 'Chi2', 0.6786], ['LSTM', 'F_classif', 0.7250], ['LSTM', 'Mutual_Info', 0.7143],
    ['GRU', 'Chi2', 0.6750], ['GRU', 'F_classif', 0.7071], ['GRU', 'Mutual_Info', 0.7214],
]

# Create DataFrame
df = pd.DataFrame(data, columns=['Model', 'Feature Selection', 'Accuracy'])

# Set plot style
sns.set(style='whitegrid')
plt.figure(figsize=(16, 8))

# Create bar plot
bar_plot = sns.barplot(data=df, x='Model', y='Accuracy', hue='Feature Selection')

# Add percentage labels on top of bars
for p in bar_plot.patches:
    height = p.get_height()
    bar_plot.text(
        p.get_x() + p.get_width() / 2.,  # x position: center of bar
        height + 0.01,                   # y position: slightly above bar
        f'{height * 100:.1f}%',          # text: percentage with 1 decimal place
        ha='center', va='bottom', fontsize=9, rotation=0
    )

# Customize plot
plt.title('Model Accuracy by Feature Selection Method', fontsize=16)
plt.xlabel('Model', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.ylim(0, 1.05)  # To leave space for labels on top
plt.xticks(rotation=30)
plt.legend(title='Feature Selection', fontsize=11, title_fontsize=12)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data setup
data = [
    ['KNN', 'Chi2', 0.7643], ['KNN', 'F_classif', 0.7643], ['KNN', 'Mutual_Info', 0.7643],
    ['SVM', 'Chi2', 0.7464], ['SVM', 'F_classif', 0.7464], ['SVM', 'Mutual_Info', 0.7464],
    ['Logistic Reg.', 'Chi2', 0.6821], ['Logistic Reg.', 'F_classif', 0.6821], ['Logistic Reg.', 'Mutual_Info', 0.6821],
    ['Random Forest', 'Chi2', 0.9036], ['Random Forest', 'F_classif', 0.9036], ['Random Forest', 'Mutual_Info', 0.9036],
    ['Decision Tree', 'Chi2', 0.7893], ['Decision Tree', 'F_classif', 0.7893], ['Decision Tree', 'Mutual_Info', 0.7893],
    ['RNN', 'Chi2', 0.6714], ['RNN', 'F_classif', 0.6964], ['RNN', 'Mutual_Info', 0.7143],
    ['LSTM', 'Chi2', 0.6786], ['LSTM', 'F_classif', 0.7250], ['LSTM', 'Mutual_Info', 0.7143],
    ['GRU', 'Chi2', 0.6750], ['GRU', 'F_classif', 0.7071], ['GRU', 'Mutual_Info', 0.7214],
]

# Create DataFrame
df = pd.DataFrame(data, columns=['Model', 'Feature Selection', 'Accuracy'])

# Pivot data for heatmap (models as rows, feature selection as columns)
heatmap_data = df.pivot(index='Model', columns='Feature Selection', values='Accuracy')

# Plot heatmap
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.1)
ax = sns.heatmap(
    heatmap_data, 
    annot=True, fmt=".2%", 
    cmap="YlGnBu", 
    cbar_kws={'label': 'Accuracy (%)'},
    linewidths=0.5,
    linecolor='gray'
)

plt.title('Accuracy Heatmap for Models and Feature Selection Methods', fontsize=16)
plt.ylabel('Model', fontsize=14)
plt.xlabel('Feature Selection Method', fontsize=14)
plt.yticks(rotation=0)  # Keep model names horizontal
plt.tight_layout()
plt.show()

# %% [markdown]
# Selected Top five model after fine tuning

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data setup (same as before)
data = [
    ['KNN', 'Chi2', 0.7643], ['KNN', 'F_classif', 0.7643], ['KNN', 'Mutual_Info', 0.7643],
    ['SVM', 'Chi2', 0.7464], ['SVM', 'F_classif', 0.7464], ['SVM', 'Mutual_Info', 0.7464],
    ['Logistic Reg.', 'Chi2', 0.6821], ['Logistic Reg.', 'F_classif', 0.6821], ['Logistic Reg.', 'Mutual_Info', 0.6821],
    ['Random Forest', 'Chi2', 0.9036], ['Random Forest', 'F_classif', 0.9036], ['Random Forest', 'Mutual_Info', 0.9036],
    ['Decision Tree', 'Chi2', 0.7893], ['Decision Tree', 'F_classif', 0.7893], ['Decision Tree', 'Mutual_Info', 0.7893],
    ['RNN', 'Chi2', 0.6714], ['RNN', 'F_classif', 0.6964], ['RNN', 'Mutual_Info', 0.7143],
    ['LSTM', 'Chi2', 0.6786], ['LSTM', 'F_classif', 0.7250], ['LSTM', 'Mutual_Info', 0.7143],
    ['GRU', 'Chi2', 0.6750], ['GRU', 'F_classif', 0.7071], ['GRU', 'Mutual_Info', 0.7214],
]

# Create DataFrame
df = pd.DataFrame(data, columns=['Model', 'Feature Selection', 'Accuracy'])

# Calculate average accuracy for each model
avg_accuracy = df.groupby('Model')['Accuracy'].mean().sort_values(ascending=False)

# Select top 5 models
top5 = avg_accuracy.head(5)

# Plot
plt.figure(figsize=(10,6))
bars = plt.bar(top5.index, top5.values * 100, color='skyblue')

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f'{height:.2f}%', ha='center', va='bottom', fontsize=10)

plt.ylabel('Average Accuracy (%)')
plt.title('Top 5 Models by Average Accuracy')
plt.ylim(0, max(top5.values)*100 + 5)  # Add some space on top for labels
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd

# Data setup (same as before)
data = [
    ['KNN', 'Chi2', 0.7643], ['KNN', 'F_classif', 0.7643], ['KNN', 'Mutual_Info', 0.7643],
    ['SVM', 'Chi2', 0.7464], ['SVM', 'F_classif', 0.7464], ['SVM', 'Mutual_Info', 0.7464],
    ['Logistic Reg.', 'Chi2', 0.6821], ['Logistic Reg.', 'F_classif', 0.6821], ['Logistic Reg.', 'Mutual_Info', 0.6821],
    ['Random Forest', 'Chi2', 0.9036], ['Random Forest', 'F_classif', 0.9036], ['Random Forest', 'Mutual_Info', 0.9036],
    ['Decision Tree', 'Chi2', 0.7893], ['Decision Tree', 'F_classif', 0.7893], ['Decision Tree', 'Mutual_Info', 0.7893],
    ['RNN', 'Chi2', 0.6714], ['RNN', 'F_classif', 0.6964], ['RNN', 'Mutual_Info', 0.7143],
    ['LSTM', 'Chi2', 0.6786], ['LSTM', 'F_classif', 0.7250], ['LSTM', 'Mutual_Info', 0.7143],
    ['GRU', 'Chi2', 0.6750], ['GRU', 'F_classif', 0.7071], ['GRU', 'Mutual_Info', 0.7214],
]

# Create DataFrame
df = pd.DataFrame(data, columns=['Model', 'Feature Selection', 'Accuracy'])

# Calculate average accuracy for each model
avg_accuracy = df.groupby('Model')['Accuracy'].mean().sort_values(ascending=False)

# Select top 5 models
top5 = avg_accuracy.head(5)

# Create a summary DataFrame
summary_df = pd.DataFrame({
    'Model': top5.index,
    'Average Accuracy (%)': (top5.values * 100).round(2)
})

# Display the table
print(summary_df.to_string(index=False))
# Out:
#         Model  Average Accuracy (%)
# Random Forest                 90.36
# Decision Tree                 78.93
#           KNN                 76.43
#           SVM                 74.64
#          LSTM                 70.60

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data setup (same as before)
data = [
    ['KNN', 'Chi2', 0.7643], ['KNN', 'F_classif', 0.7643], ['KNN', 'Mutual_Info', 0.7643],
    ['SVM', 'Chi2', 0.7464], ['SVM', 'F_classif', 0.7464], ['SVM', 'Mutual_Info', 0.7464],
    ['Logistic Reg.', 'Chi2', 0.6821], ['Logistic Reg.', 'F_classif', 0.6821], ['Logistic Reg.', 'Mutual_Info', 0.6821],
    ['Random Forest', 'Chi2', 0.9036], ['Random Forest', 'F_classif', 0.9036], ['Random Forest', 'Mutual_Info', 0.9036],
    ['Decision Tree', 'Chi2', 0.7893], ['Decision Tree', 'F_classif', 0.7893], ['Decision Tree', 'Mutual_Info', 0.7893],
    ['RNN', 'Chi2', 0.6714], ['RNN', 'F_classif', 0.6964], ['RNN', 'Mutual_Info', 0.7143],
    ['LSTM', 'Chi2', 0.6786], ['LSTM', 'F_classif', 0.7250], ['LSTM', 'Mutual_Info', 0.7143],
    ['GRU', 'Chi2', 0.6750], ['GRU', 'F_classif', 0.7071], ['GRU', 'Mutual_Info', 0.7214],
]

# Create DataFrame
df = pd.DataFrame(data, columns=['Model', 'Feature Selection', 'Accuracy'])

# Calculate average accuracy for each model
avg_accuracy = df.groupby('Model')['Accuracy'].mean().sort_values(ascending=False)

# Select top 5 models based on average accuracy
top5_models = avg_accuracy.head(5).index.tolist()

# Filter data for only top 5 models
top5_df = df[df['Model'].isin(top5_models)]

# Pivot data for heatmap
heatmap_data = top5_df.pivot(index='Model', columns='Feature Selection', values='Accuracy')

# Plot heatmap
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.1)
ax = sns.heatmap(
    heatmap_data, 
    annot=True, fmt=".2%", 
    cmap="YlGnBu", 
    cbar_kws={'label': 'Accuracy (%)'},
    linewidths=0.5,
    linecolor='gray'
)

plt.title('Top 5 Models Accuracy Heatmap', fontsize=16)
plt.ylabel('Model', fontsize=14)
plt.xlabel('Feature Selection Method', fontsize=14)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# --- Step 1: Data ---
data = {
    'Sr No': [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6, 7, 7, 7, 8, 8, 8],
    'Model': ['Decision Tree', 'Decision Tree', 'Decision Tree', 'Logistic Reg.', 'Logistic Reg.', 'Logistic Reg.',
              'Random Forest', 'Random Forest', 'Random Forest', 'SVM', 'SVM', 'SVM', 'KNN', 'KNN', 'KNN',
              'GRU', 'GRU', 'GRU', 'LSTM', 'LSTM', 'LSTM', 'RNN', 'RNN', 'RNN'],
    'Feature Selection': ['Chi2', 'F_classif', 'Mutual_Info'] * 8,
    'Accuracy': [0.7476, 0.7476, 0.8333, 0.6381, 0.6381, 0.5619, 0.8905, 0.8905, 0.8952, 0.6238, 0.7905, 0.7476, 0.6571,
                 0.7048, 0.6714, 0.8165, 0.8354, 0.8239, 0.8094, 0.8251, 0.8189, 0.8034, 0.8203, 0.8150],
    'Precision': [0.7008, 0.7008, 0.8165, 0.6207, 0.6207, 0.5462, 0.8932, 0.8932, 0.9020, 0.5767, 0.7632, 0.7257, 0.6633,
                  0.6810, 0.6522, 0.8065, 0.8201, 0.8149, 0.8031, 0.8148, 0.8117, 0.7923, 0.8062, 0.8036],
    'Recall (Sensitivity)': [0.8558, 0.8558, 0.8558, 0.6923, 0.6923, 0.6827, 0.8846, 0.8846, 0.8846, 0.9038, 0.8365, 0.7885, 0.6250,
                             0.7596, 0.7212, 0.8237, 0.8403, 0.8294, 0.8202, 0.8304, 0.8261, 0.8146, 0.8239, 0.8240],
    'Specificity': [0.6415, 0.6415, 0.8113, 0.5849, 0.5849, 0.4434, 0.8962, 0.8962, 0.9057, 0.3491, 0.7453, 0.7075, 0.6887,
                    0.6509, 0.6226, 0.8037, 0.8064, 0.8087, 0.7903, 0.8030, 0.7974, 0.7819, 0.7958, 0.7916],
    'F1-Score': [0.7706, 0.7706, 0.8357, 0.6545, 0.6545, 0.6068, 0.8889, 0.8889, 0.8932, 0.7041, 0.7982, 0.7558, 0.6436,
                 0.7182, 0.6849, 0.8150, 0.8282, 0.8215, 0.8115, 0.8217, 0.8190, 0.8034, 0.8148, 0.8124]
}
df = pd.DataFrame(data)

# --- Step 2: Simulate confusion matrix ---
def simulate_confusion_matrix(accuracy, precision, recall, specificity, total=1400):
    try:
        TP = recall * precision * total / (recall + precision - recall * precision)
        FP = TP * (1 / precision - 1)
        FN = TP * (1 / recall - 1)
        TN = FP * (specificity / (1 - specificity))
    except ZeroDivisionError:
        TP = FP = FN = TN = 0
    return np.array([[int(TN), int(FP)], [int(FN), int(TP)]])

# --- Step 3: Plot confusion matrices grouped by model ---
unique_models = df['Model'].unique()

for model_name in unique_models:
    subset = df[df['Model'] == model_name]
    feature_names = ['Chi2', 'F_classif', 'Mutual_Info']
    
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 4))
    fig.suptitle(f'Confusion Matrices for {model_name}', fontsize=14)

    for i, (index, row) in enumerate(subset.iterrows()):
        cm = simulate_confusion_matrix(row['Accuracy'], row['Precision'], row['Recall (Sensitivity)'], row['Specificity'])
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Negative', 'Positive'])
        disp.plot(ax=axes[i], cmap='Blues', values_format='d', colorbar=False)
        axes[i].set_title(f"{feature_names[i]}")

    plt.tight_layout(rect=[0, 0.03, 1, 0.90])
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Data and columns
data = [
    ['KNN', 'Chi2', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.22],
    ['KNN', 'F_classif', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.04],
    ['KNN', 'Mutual_Info', 0.7643, 0.7372, 0.8214, 0.7770, 0.8214, 0.7071, 0.04],
    ['SVM', 'Chi2', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.15],
    ['SVM', 'F_classif', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.14],
    ['SVM', 'Mutual_Info', 0.7464, 0.7143, 0.8214, 0.7641, 0.8214, 0.6714, 0.16],
    ['Logistic Reg.', 'Chi2', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.02],
    ['Logistic Reg.', 'F_classif', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.01],
    ['Logistic Reg.', 'Mutual_Info', 0.6821, 0.6711, 0.7143, 0.6920, 0.7143, 0.6500, 0.01],
    ['Random Forest', 'Chi2', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.35],
    ['Random Forest', 'F_classif', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.33],
    ['Random Forest', 'Mutual_Info', 0.9036, 0.9007, 0.9071, 0.9039, 0.9071, 0.9000, 0.35],
    ['Decision Tree', 'Chi2', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.03],
    ['Decision Tree', 'F_classif', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.03],
    ['Decision Tree', 'Mutual_Info', 0.7893, 0.7755, 0.8143, 0.7944, 0.8143, 0.7643, 0.02],
    ['RNN', 'Chi2', 0.6714, 0.6481, 0.7500, 0.6954, 0.7500, 0.5929, 6.00],
    ['RNN', 'F_classif', 0.6964, 0.6846, 0.7286, 0.7059, 0.7286, 0.6643, 6.22],
    ['RNN', 'Mutual_Info', 0.7143, 0.7143, 0.7143, 0.7143, 0.7143, 0.7143, 6.20],
    ['LSTM', 'Chi2', 0.6786, 0.6562, 0.7500, 0.7000, 0.7500, 0.6071, 6.93],
    ['LSTM', 'F_classif', 0.7250, 0.7114, 0.7571, 0.7336, 0.7571, 0.6929, 6.96],
    ['LSTM', 'Mutual_Info', 0.7143, 0.6974, 0.7571, 0.7260, 0.7571, 0.6714, 7.23],
    ['GRU', 'Chi2', 0.6750, 0.6522, 0.7500, 0.6977, 0.7500, 0.6000, 6.05],
    ['GRU', 'F_classif', 0.7071, 0.6859, 0.7643, 0.7230, 0.7643, 0.6500, 6.87],
    ['GRU', 'Mutual_Info', 0.7214, 0.7039, 0.7643, 0.7329, 0.7643, 0.6786, 6.89],
]

columns = ['Model', 'Feature Selection', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Sensitivity', 'Specificity', 'Time (s)']
df = pd.DataFrame(data, columns=columns)

# Simulate confusion matrix
def simulate_conf_matrix(accuracy, precision, recall, specificity, total=1400):
    try:
        TP = recall * precision * total / (recall + precision - recall * precision)
        FP = TP * (1 / precision - 1)
        FN = TP * (1 / recall - 1)
        TN = FP * (specificity / (1 - specificity))
    except ZeroDivisionError:
        TP = FP = FN = TN = 0
    return np.array([[int(TN), int(FP)], [int(FN), int(TP)]])

# Generate confusion matrices grouped by model
import matplotlib.pyplot as plt
unique_models = df['Model'].unique()

for model in unique_models:
    subset = df[df['Model'] == model].reset_index()
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    fig.suptitle(f'Confusion Matrices for {model}', fontsize=14)
    
    for i, row in subset.iterrows():
        cm = simulate_conf_matrix(row['Accuracy'], row['Precision'], row['Recall'], row['Specificity'])
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Negative", "Positive"])
        disp.plot(ax=axes[i], cmap='Blues', colorbar=False, values_format='d')
        axes[i].set_title(row['Feature Selection'])
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.90])
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Before fine-tuning data
data = {
    'Sr No': [1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6, 7, 7, 7, 8, 8, 8],
    'Model': ['Decision Tree', 'Decision Tree', 'Decision Tree', 'Logistic Reg.', 'Logistic Reg.', 'Logistic Reg.',
              'Random Forest', 'Random Forest', 'Random Forest', 'SVM', 'SVM', 'SVM', 'KNN', 'KNN', 'KNN',
              'GRU', 'GRU', 'GRU', 'LSTM', 'LSTM', 'LSTM', 'RNN', 'RNN', 'RNN'],
    'Feature Selection': ['Chi2', 'F_classif', 'Mutual_Info'] * 8,
    'Accuracy': [0.7476, 0.7476, 0.8333, 0.6381, 0.6381, 0.5619, 0.8905, 0.8905, 0.8952,
                 0.6238, 0.7905, 0.7476, 0.6571, 0.7048, 0.6714, 0.8165, 0.8354, 0.8239,
                 0.8094, 0.8251, 0.8189, 0.8034, 0.8203, 0.8150],
    'Precision': [0.7008, 0.7008, 0.8165, 0.6207, 0.6207, 0.5462, 0.8932, 0.8932, 0.9020,
                  0.5767, 0.7632, 0.7257, 0.6633, 0.6810, 0.6522, 0.8065, 0.8201, 0.8149,
                  0.8031, 0.8148, 0.8117, 0.7923, 0.8062, 0.8036],
    'Recall': [0.8558, 0.8558, 0.8558, 0.6923, 0.6923, 0.6827, 0.8846, 0.8846, 0.8846,
               0.9038, 0.8365, 0.7885, 0.6250, 0.7596, 0.7212, 0.8237, 0.8403, 0.8294,
               0.8202, 0.8304, 0.8261, 0.8146, 0.8239, 0.8240],
    'F1 Score': [0.7706, 0.7706, 0.8357, 0.6545, 0.6545, 0.6068, 0.8889, 0.8889, 0.8932,
                 0.7041, 0.7982, 0.7558, 0.6436, 0.7182, 0.6849, 0.8150, 0.8282, 0.8215,
                 0.8115, 0.8217, 0.8190, 0.8034, 0.8148, 0.8124]
}

# Create DataFrame
df = pd.DataFrame(data)

# Combine Model and Feature Selection for labeling
df['Label'] = df['Model'] + '\n(' + df['Feature Selection'] + ')'
df_plot = df[['Label', 'Accuracy', 'Precision', 'Recall', 'F1 Score']].set_index('Label')

# Plot
ax = df_plot.plot(kind='bar', figsize=(18, 8), width=0.8)
plt.title('Model Performance Before Fine-Tuning', fontsize=16)
plt.ylabel('Score')
plt.xticks(rotation=90)
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Legend at bottom left
plt.legend(loc='lower left', bbox_to_anchor=(0.0, -0.35), ncol=4, fontsize=10, frameon=False)

# Add values above bars
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{height:.2f}',
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom',
                    fontsize=8, rotation=90,
                    xytext=(0, 3), textcoords='offset points')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# After fine-tuning data
data = [
    ['KNN', 'Chi2', 0.7643, 0.7372, 0.8214, 0.7770],
    ['KNN', 'F_classif', 0.7643, 0.7372, 0.8214, 0.7770],
    ['KNN', 'Mutual_Info', 0.7643, 0.7372, 0.8214, 0.7770],

    ['SVM', 'Chi2', 0.7464, 0.7143, 0.8214, 0.7641],
    ['SVM', 'F_classif', 0.7464, 0.7143, 0.8214, 0.7641],
    ['SVM', 'Mutual_Info', 0.7464, 0.7143, 0.8214, 0.7641],

    ['Logistic Reg.', 'Chi2', 0.6821, 0.6711, 0.7143, 0.6920],
    ['Logistic Reg.', 'F_classif', 0.6821, 0.6711, 0.7143, 0.6920],
    ['Logistic Reg.', 'Mutual_Info', 0.6821, 0.6711, 0.7143, 0.6920],

    ['Random Forest', 'Chi2', 0.9036, 0.9007, 0.9071, 0.9039],
    ['Random Forest', 'F_classif', 0.9036, 0.9007, 0.9071, 0.9039],
    ['Random Forest', 'Mutual_Info', 0.9036, 0.9007, 0.9071, 0.9039],

    ['Decision Tree', 'Chi2', 0.7893, 0.7755, 0.8143, 0.7944],
    ['Decision Tree', 'F_classif', 0.7893, 0.7755, 0.8143, 0.7944],
    ['Decision Tree', 'Mutual_Info', 0.7893, 0.7755, 0.8143, 0.7944],

    ['RNN', 'Chi2', 0.6714, 0.6481, 0.7500, 0.6954],
    ['RNN', 'F_classif', 0.6964, 0.6846, 0.7286, 0.7059],
    ['RNN', 'Mutual_Info', 0.7143, 0.7143, 0.7143, 0.7143],

    ['LSTM', 'Chi2', 0.6786, 0.6562, 0.7500, 0.7000],
    ['LSTM', 'F_classif', 0.7250, 0.7114, 0.7571, 0.7336],
    ['LSTM', 'Mutual_Info', 0.7143, 0.6974, 0.7571, 0.7260],

    ['GRU', 'Chi2', 0.6750, 0.6522, 0.7500, 0.6977],
    ['GRU', 'F_classif', 0.7071, 0.6859, 0.7643, 0.7230],
    ['GRU', 'Mutual_Info', 0.7214, 0.7039, 0.7643, 0.7329],
]

# Columns
columns = ['Model', 'Feature Selection', 'Accuracy', 'Precision', 'Recall', 'F1 Score']
df = pd.DataFrame(data, columns=columns)

# Combine Model + Feature Selection for X-axis
df['Label'] = df['Model'] + '\n(' + df['Feature Selection'] + ')'
df_plot = df[['Label', 'Accuracy', 'Precision', 'Recall', 'F1 Score']].set_index('Label')

# Plot
ax = df_plot.plot(kind='bar', figsize=(18, 8), width=0.8)
plt.title('Model Performance After Fine-Tuning', fontsize=16)
plt.ylabel('Score')
plt.xticks(rotation=90)
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Legend at bottom left
plt.legend(loc='lower left', bbox_to_anchor=(0.0, -0.35), ncol=4, fontsize=10, frameon=False)

# Annotate each bar
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{height:.2f}',
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom',
                    fontsize=8, rotation=90,
                    xytext=(0, 3), textcoords='offset points')

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# %%
# Example assuming binary classification and these are available:
# y_true, y_proba_knn, y_proba_svm, ...

models_before = {
    'KNN': y_proba_knn,
    'SVM': y_proba_svm,
    'Logistic Reg.': y_proba_logreg,
    'Random Forest': y_proba_rf,
    'Decision Tree': y_proba_dt,
    'RNN': y_proba_rnn,
    'LSTM': y_proba_lstm,
    'GRU': y_proba_gru
}

plt.figure(figsize=(10, 8))

for model_name, y_proba in models_before.items():
    fpr, tpr, _ = roc_curve(y_true, y_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Random line
plt.title('ROC Curve (Before Fine-Tuning)', fontsize=14)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 # Example assuming binary classification and these are available:
#       2 # y_true, y_proba_knn, y_proba_svm, ...
#       4 models_before = {
# ----> 5     'KNN': y_proba_knn,
#       6     'SVM': y_proba_svm,
#       7     'Logistic Reg.': y_proba_logreg,
#       8     'Random Forest': y_proba_rf,
#       9     'Decision Tree': y_proba_dt,
#      10     'RNN': y_proba_rnn,
#      11     'LSTM': y_proba_lstm,
#      12     'GRU': y_proba_gru
#      13 }
#      15 plt.figure(figsize=(10, 8))
#      17 for model_name, y_proba in models_before.items():
#
# NameError: name 'y_proba_knn' is not defined
